# %% [markdown]
# # (@ We Rate Dogs) Data Wrangling Project

# %% [markdown]
# ## Insight and Visualization Report

# %% [markdown]
# **Firstly, lets start with the full correlation insight among all attributes, and its as the following:**
# ![image.png](attachment:image.png)

# %% [markdown]
# **We can get from the above correlation heatmap the following insights:**
# - there is only one linear correlation appears between retweet count and favrorite count which can be represented on the following strong relation
# ![image.png](attachment:image.png)

# %% [markdown]
# - As per the correlation heatmap we double checked the relation between favorite count and rating numerator, its clear that there is no correlation as the following
# ![image.png](attachment:image.png)

# %% [markdown]
# - As per the wrangling report, new two columns were added for the Hour of Day and Day of Week to check if there are a relation between the retweet/favorit counts and day/hour of week/day, and got the following:
#     - **Day of Week**
#     ![image.png](attachment:image.png)
#         - It seems that its normally disributed no big varaince among days of week

# %% [markdown]
#    - **Hour of Day**
# ![image.png](attachment:image.png)
#
#         - the followers tends to retweet/like we rate dogs account on none working hours and specially at night

# %% [markdown]
# **Secondly, lets have a look at the dog stages with dog breeds vs retweet counts:***
# ![dog_breads2.png](attachment:dog_breads2.png)
#
# We found that pupper and doggo have the largest count and higthest rating in average

# %% [markdown]
# ![dog_breads.png](attachment:dog_breads.png)

# %% [markdown]
# **Finally, lets view an visuization chart, displaying top 25 dog breed used in rating data, and view its retweet and favorit sums, retweet and favorit means, and rating numerator mean**
# ![image.png](attachment:image.png)
#
#    - We found that, Golden Retreiever has the highest likes count, while the French Bulldog has the highest average of likes
